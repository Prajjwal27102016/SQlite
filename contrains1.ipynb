# %%
import sqlite3

conn = sqlite3.connect('database.sqlite')

print("Opened database successfully")

conn.execute('''DROP TABLE IF EXISTS CLASS_10;''')
conn.execute('''CREATE TABLE CLASS_10
                (SNO INT PRIMARY KEY NOT NULL,
                Roll_No INT NOT NULL,
                Name TEXT NOT NULL,
                AGE INT DEFAULT (15),
                GENDER TEXT NOT NULL,
                Email_ID TEXT NOT NULL,
                Contact_No REAL NOT NULL);''')
conn.commit()

print("Table created successfully")
# Out:
# Opened database successfully
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[2], line 7
#       3 conn = sqlite3.connect('database.sqlite')
#       5 print("Opened database successfully")
# ----> 7 conn.execute('''CREATE TABLE CLASS_10
#       8                 (SNO INT PRIMARY KEY NOT NULL,
#       9                 Roll_No INT NOT NULL,
#      10                 Name TEXT NOT NULL,
#      11                 AGE INT DEFAULT (15),
#      12                 GENDER TEXT NOT NULL,
#      13                 Email_ID TEXT NOT NULL,
#      14                 Contact_No REAL NOT NULL);''')
#      16 print("Table created successfully")
#
# OperationalError: table CLASS_10 already exists
